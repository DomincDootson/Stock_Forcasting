# %% [markdown]
# # Future Stock Prediction

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# So the aim of this notebook will be to train ARIMA, PROPHET and LSTM/GRU models to predict future stock prices. In this notebook we will use Apple historical data.
#
# https://neptune.ai/blog/arima-vs-prophet-vs-lstm

# %%
stock = pd.read_csv('AAPL_FULL_2012_2022.csv', index_col  ='Date') # We need to do something with the index
train, test = stock.iloc[:2000], stock.iloc[2000:] # this will give a 80-20 train test split

# %%
plt.plot(range(2000), train['AAPL_Close'], label = 'Train')
plt.plot(range(2000,len(stock)), test['AAPL_Close'], label = 'Test')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Apple Stock Price')
plt.legend()
           
plt.show()

# %% [markdown]
# In order to create better predictions, we will feature engineer some lagging indicies based on information other than the close price:
#
# - High, mean and std
# - Low, mean and std
# - Volume, mean and std
#
# And we will do this for a variety of different lagging periods from 3 days to 30.

# %%
def get_lagged_data(df, feature, window):
    return df[feature].rolling(window = window)

def get_lagged_mean(df, feature, window):
    lagged_data = get_lagged_data(df, feature, window)
    return lagged_data.mean().shift(1).reset_index()#.astype(np.float32)

def get_lagged_std(df, feature, window):
    lagged_data = get_lagged_data(df, feature, window)
    return lagged_data.std().shift(1).reset_index()#.astype(np.float32)

# %%
fig, axs = plt.subplots(ncols = 2)
axs[0].plot(get_lagged_mean(stock, 'AAPL_High', 30)['AAPL_High'])
axs[1].plot(get_lagged_std(stock, 'AAPL_High', 30)['AAPL_High'])
plt.show()

# %%
stock.head()
# Out:
#             AAPL_Open  AAPL_High   AAPL_Low  AAPL_Close  AAPL_Adj Close  \
# Date
# 2012-01-03  14.621429  14.732143  14.607143   14.686786       12.433824
# 2012-01-04  14.642857  14.810000  14.617143   14.765714       12.500644
# 2012-01-05  14.819643  14.948214  14.738214   14.929643       12.639426
# 2012-01-06  14.991786  15.098214  14.972143   15.085714       12.771556
# 2012-01-09  15.196429  15.276786  15.048214   15.061786       12.751300
#
#             AAPL_Volume
# Date
# 2012-01-03    302220800
# 2012-01-04    260022000
# 2012-01-05    271269600
# 2012-01-06    318292800
# 2012-01-09    394024400

# %%
lag = [3, 7, 30]
for feature in stock.columns:
    for l in lag:
        
        stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
        stock[feature + f"_mean_lag{l}"] = get_lagged_std(stock, feature, l)[feature]
    


stock['AAPL_Open_mean_lag3']
# Out:
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# /var/folders/bf/mw0q8tbn2h9gdx1cdb2w33jc0000gn/T/ipykernel_3426/2262660421.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stock[feature + f"_mean_lag{l}"] = get_lagged_mean(stock, feature, l)[feature]
# Date
# 2012-01-03   NaN
# 2012-01-04   NaN
# 2012-01-05   NaN
# 2012-01-06   NaN
# 2012-01-09   NaN
#               ..
# 2021-12-27   NaN
# 2021-12-28   NaN
# 2021-12-29   NaN
# 2021-12-30   NaN
# 2021-12-31   NaN
# Name: AAPL_Open_mean_lag3, Length: 2517, dtype: float64
